# %%
type(2)
# Out:
# int

# %%
students = [ "andrew", "robert", "ping", "ryan"]

# %%
students.pop(1)
# Out:
# 'robert'

# %%
students
# Out:
# ['andrew', 'ping', 'ryan']

# %%
students.remove("ping")

# %%
students
# Out:
# ['andrew', 'ryan']

# %%
students.append("greg")

# %%
sorted(students, reverse=True)
# Out:
# ['ryan', 'greg', 'andrew']

# %%
", ".join(students)
# Out:
# 'andrew, ryan, greg'

# %%
u_data = ("Ronald",18)

# %%
type(u_data)
# Out:
# tuple

# %%
#tuples are immutable

# %%
sat_scores = 700, 710, 780

# %%
type(sat_scores)
# Out:
# tuple

# %%
degrees = {"BsC", "MA", "ECE", "CoE"}

# %%
type(degrees)
# Out:
# set

# %%
degrees.add("BA")

# %%
degrees
# Out:
# {'BA', 'BsC', 'CoE', 'ECE', 'MA'}

# %%
degrees.discard("ECE")

# %%
degrees
# Out:
# {'BA', 'BsC', 'CoE', 'MA'}

# %%
degrees2 = {"BSN", "BSIT", "ECE", "MA"}

# %%
degrees.intersection(degrees2)
# Out:
# {'MA'}

# %%
degrees.union(degrees2)
# Out:
# {'BA', 'BSIT', 'BSN', 'BsC', 'CoE', 'ECE', 'MA'}

# %%
degrees.difference(degrees2)
# Out:
# {'BA', 'BsC', 'CoE'}

# %%
student_scores = {
    "Andrew" : 96,
    "Joan" : 98,
    "Ben": 86,
    "Rudolf": 74
}

# %%
"Ben" in student_scores
# Out:
# True

# %%
names = ["Andrew", "Ryan", "Angela", "Shea"]
scores = [95,93,90,98]
attendance = [ True, True,True,True]

# %%
zip(names,scores)

# %%
list(zip(names,scores))
# Out:
# [('Andrew', 95), ('Ryan', 93), ('Angela', 90), ('Shea', 98)]

# %%
for stundent_name, student_score in zip(names,scores):
    print(f"name: {stundent_name} - score: {student_score}")
# Out:
# name: Andrew - score: 95
# name: Ryan - score: 93
# name: Angela - score: 90
# name: Shea - score: 98

# %%
list(zip(names,scores,attendance))
# Out:
# [('Andrew', 95, True),
#  ('Ryan', 93, True),
#  ('Angela', 90, True),
#  ('Shea', 98, True)]

# %%
numbers = [10,2,4,12,13,1,712,23,2,192] 

student = [ {"name": "Andrea", "score": 90},
            {"name": "Jane", "score": 85},
            {"name": "Ruth", "score": 91},
            {"name": "Shea", "score": 98}]

# %%
even = sorted([x for x in numbers if x%2 == 0])

odd = sorted([x for x in numbers if x%2 != 0])

# %%
odd
# Out:
# [1, 13, 23]

# %%
even
# Out:
# [2, 2, 4, 10, 12, 192, 712]

# %%
above_90 = [x for x in student if x["score"] >= 90]

# %%
above_90
# Out:
# [{'name': 'Andrea', 'score': 90},
#  {'name': 'Ruth', 'score': 91},
#  {'name': 'Shea', 'score': 98}]

# %%
get_above_90 = [x for x in student if x.get("score") >= 90]

# %%
get_above_90
# Out:
# [{'name': 'Andrea', 'score': 90},
#  {'name': 'Ruth', 'score': 91},
#  {'name': 'Shea', 'score': 98}]

# %%
students_above_90 = [x.get("name") for x in student if x.get("score") >= 90]

# %%
students_above_90
# Out:
# ['Andrea', 'Ruth', 'Shea']

# %%
from statistics import mean

ave_score = mean([x.get("score") for x in  student])

# %%
ave_score
# Out:
# 91

# %%
def get_average_score(scores_list):
    return [ sum(x.get("scores")) / len(x["scores"]) for x in student_scores]

# %%
student_scores = [{"name": "Joan", "scores": [90,73,43,100]},
                  {"name": "Ray", "scores": [69,83,93,75]},
                  {"name": "Tin", "scores": [86,87,85,91]}]

# %%
get_average_score([x for x in student_scores])
# Out:
# [76.5, 80.0, 87.25]

# %%
name = "Mary Anderson"

# %%
def interchange(name):
    name = name.split()
    return f"{name[-1]}, {name[0]}"

# %%
interchange(name)
# Out:
# 'Anderson, Mary'

# %%
def reverse_name(first,last):
    return "{}, {}".format(last,first)

# %%
reverse_name("Mary","Anderson")
# Out:
# 'Anderson, Mary'

# %%
lambda x: x**3
# Out:
# <function __main__.<lambda>(x)>

# %%
a = 10

# %%
_(a)
# Out:
# 1000

# %%
cube_it = lambda x: x**3

# %%
cube_it(10)
# Out:
# 1000

# %%
numbers = [10,2,4,12,13,1,712,23,2,192]

# %%
map(cube_it,numbers)

# %%
list(map(cube_it,numbers))
# Out:
# [1000, 8, 64, 1728, 2197, 1, 360944128, 12167, 8, 7077888]
