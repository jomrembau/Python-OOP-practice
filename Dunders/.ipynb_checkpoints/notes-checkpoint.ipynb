# %% [markdown]
# # __repr__

# %%
class Book:
    def __init__(self, title, author,book_type,pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

# %%
book1 = Book("Art of War", "Sun Tzu", "Hardcover", "120")

# %%
book1

# %%
repr(book1)
# Out:
# '<__main__.Book object at 0x000001DBF43DD610>'

# %%
class Book:
    def __init__(self, title, author, book_type, pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

    def __repr__(self):
        return f"Book Title: {self.title}"

# %%
book1 = Book("Art of War", "Sun Tzu", "Hardcover", "120")

# %%
book1
# Out:
# Book Title: Art of War

# %%
print(book1)
# Out:
# Book Title: Art of War

# %%
class Book:
    def __init__(self, title, author, book_type, pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

    def __repr__(self):
        return f'Book("{self.title}", "{self.author}", "{self.book_type}", {self.pages})'

    def __str__(self):
        return f"{self.title} by {self.author} in {self.book_type}"

# %%
book1 = Book("Art of War", "Sun Tzu", "Hardcover", "120")

# %%
str(book1)
# Out:
# 'Art of War by Sun Tzu in Hardcover'

# %%
#__str__ for end user
# __repr__ for devs

# %%
repr(book1)
# Out:
# 'Book("Art of War", "Sun Tzu", "Hardcover", 120)'

# %%
eval(repr(book1))
# Out:
# Book("Art of War", "Sun Tzu", "Hardcover", 120)

# %% [markdown]
# # __format__

# %%
format(100,"3f")
# Out:
# '100.000000'

# %%
class Book:
    def __init__(self, title, author, book_type, pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

    def __repr__(self):
        return f'Book("{self.title}", "{self.author}", "{self.book_type}", {self.pages})'

    def __format__(self, format_spec):
        if format_spec == "short":
            return f"{self.title}"

# %%
book1 = Book("Art of War", "Sun Tzu", "Hardcover", "120")
book2 = Book("Art of War", "Sun Tzu", "Hardcover", "120")

# %%
id(book1)
# Out:
# 2044211358096

# %%
id(book2)
# Out:
# 2044211500176

# %%
class Book:
    def __init__(self, title, author, book_type, pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

    def __repr__(self):
        return f'Book("{self.title}", "{self.author}", "{self.book_type}", {self.pages})'

    def __eq__(self,other):
        return True

# %%
book1 = Book("Art of War", "Sun Tzu", "Hardcover", "120")
book2 = Book("Art of War", "Sun Tzu", "Hardcover", "120")

# %%
book1 == book2
# Out:
# True

# %% [markdown]
# Named Tuple

# %%
from collections import namedtuple

essay = namedtuple("essay", ("title","author"))

# %%
e = essay("The Art of War", "Sun Tzu")

# %%
e.title
# Out:
# 'The Art of War'

# %%
e.author
# Out:
# 'Sun Tzu'

# %%
class Book:
    def __init__(self, title, author, book_type, pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

    def __repr__(self):
        return f'Book("{self.title}", "{self.author}", "{self.book_type}", {self.pages})'

    def __eq__(self,other):
        if  not isinstance(other,book):
            return False
        return self.title == other.title and self.author == other.author

    def __ne__(self,other):
        print("Comparing non-equality")

        if not isinstance(other,Book):
            return False

        return self.title != other.title and self.author != other.author

# %% [markdown]
# # Hashing and Mutability

# %%
# hashable colud be comppared to other objects

# %%
hash(book1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 hash(book1)
#
# TypeError: unhashable type: 'Book'

# %%
# Book class unhashsable due to __eq__

# %%
class Book:
    def __init__(self, title, author, book_type, pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

    def __repr__(self):
        return f'Book("{self.title}", "{self.author}", "{self.book_type}", {self.pages})'

    def __eq__(self,other):
        if  not isinstance(other,book):
            return False
        return self.title == other.title and self.author == other.author

    def __hash__(self):
        return hash((self.title, self.author))

# %% [markdown]
# # Greater than

# %%
class Book:
    def __init__(self, title, author, book_type, pages):
        self.title = title
        self.author = author
        self.book_type = book_type
        self.pages = pages

    def __repr__(self):
        return f'Book("{self.title}", "{self.author}", "{self.book_type}", {self.pages})'

    def __eq__(self,other):
        if  not isinstance(other,book):
            return False
        return self.title == other.title and self.author == other.author

    def __gt__(self,other):
        if not isinstance(other,Book):
            return NotImplemented
        return self.pages > other.pages

    def __hash__(self):
        return hash((self.title, self.author))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 book1 > book2
#
# TypeError: '>' not supported between instances of 'Book' and 'Book'
